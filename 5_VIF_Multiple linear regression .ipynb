# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\HP\Desktop\Machine Learning\mul_regression.csv")

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
x = data.iloc[:, :-1]
x
# Out:
#     R&D Spend  Administration  Marketing Spend       State
# 0   165349.20       136897.80        471784.10    New York
# 1   162597.70       151377.59        443898.53  California
# 2   153441.51       101145.55        407934.54     Florida
# 3   144372.41       118671.85        383199.62    New York
# 4   142107.34        91391.77        366168.42     Florida
# 5   131876.90        99814.71        362861.36    New York
# 6   134615.46       147198.87        127716.82  California
# 7   130298.13       145530.06        323876.68     Florida
# 8   120542.52       148718.95        311613.29    New York
# 9   123334.88       108679.17        304981.62  California
# 10  101913.08       110594.11        229160.95     Florida
# 11  100671.96        91790.61        249744.55  California
# 12   93863.75       127320.38        249839.44     Florida
# 13   91992.39       135495.07        252664.93  California
# 14  119943.24       156547.42        256512.92     Florida
# ...

# %%
y = data.iloc[:,-1].values
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %% [raw]
# # Feature Encoding
# Example column state has 3 unique catagories california, Newyork and Florida
#
# Now we have to convert categorical data to nemerical data
#
# There are 2 types of encoding:
#    1. Label encoding
#         Ex: Gender : Male and Female
#             Assign Male with value 0 and Female with value 1
#    2. One hot encoding
#
#    In the above state column, 1 column(i.e., state) is converted to 3 columns, has there are 3 unique catagories. We can derive 1 column if we know other 2 column.
#    If there are 'n' unique catogories in column then n columns are created.
#
# VIF should not be greater than 3.

# %%
res = pd.get_dummies(x['State'])   # get_dummies will convert categorical data to numerical
res.head()                                # get_dummies performs one hot encoding
# Out:
#    California  Florida  New York
# 0           0        0         1
# 1           1        0         0
# 2           0        1         0
# 3           0        0         1
# 4           0        1         0

# %%
x = x.drop(['State'], axis = 1)   # drop is a function used to drop either rows or columns by giving specific numbers

#axis = 0 means drop rowwise and axis =1 means drop columnwise

# %%
x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  165349.20       136897.80        471784.10
# 1  162597.70       151377.59        443898.53
# 2  153441.51       101145.55        407934.54
# 3  144372.41       118671.85        383199.62
# 4  142107.34        91391.77        366168.42

# %% [raw]
# Now x is having only 3 columns because we dropped the state column.
#
# Now concatenate res with x.
#
# res has data of state

# %%
x = pd.concat((x, res), axis =1)
x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  California  Florida  New York
# 0  165349.20       136897.80        471784.10           0        0         1
# 1  162597.70       151377.59        443898.53           1        0         0
# 2  153441.51       101145.55        407934.54           0        1         0
# 3  144372.41       118671.85        383199.62           0        0         1
# 4  142107.34        91391.77        366168.42           0        1         0

# %%
import seaborn as sb
# %matplotlib inline

# %%
sb.boxplot(x['R&D Spend'])   #boxplot to check outliers in column  R&D Spend. Similarly we can do it for other columns
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='R&D Spend'>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

# %%
x['intercept'] = 1  #create a column intercept with value = 1

# %%
x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  California  Florida  New York  \
# 0  165349.20       136897.80        471784.10           0        0         1
# 1  162597.70       151377.59        443898.53           1        0         0
# 2  153441.51       101145.55        407934.54           0        1         0
# 3  144372.41       118671.85        383199.62           0        0         1
# 4  142107.34        91391.77        366168.42           0        1         0
#
#    intercept
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
VIF = pd.DataFrame()  #create empty dataframe

# %%
VIF
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
VIF['variables'] = x.columns  # create a column called variables in empty dataframe, values are the column names of the x

# %%
VIF
# Out:
#          variables
# 0        R&D Spend
# 1   Administration
# 2  Marketing Spend
# 3       California
# 4          Florida
# 5         New York
# 6        intercept

# %%
VIF['vif'] = [vif(x.values,i) for i in range(x.shape[1])]

# %% [raw]
#  list comprehension # wen we run this line 2nd time there will be no warning symbol, because there is no infinity

# %%
x.shape[0]  #gives no. of rows
# Out:
# 50

# %%
x.shape[1]  #gives no. of columns
# Out:
# 7

# %%
x.shape
# Out:
# (50, 7)

# %%
VIF
# Out:
#          variables       vif
# 0        R&D Spend  2.495511
# 1   Administration  1.177766
# 2  Marketing Spend  2.416797
# 3       California       inf
# 4          Florida       inf
# 5         New York       inf
# 6        intercept  0.000000

# %% [raw]
# inf- infinity indicates dependency
#
# vif shoul not be greater than 3

# %%
x = x.drop('California', axis = 1)  # drop any one column either California, Florida or Newyork
x.head()                            # drop only one column to avoid multicollinearity

#drop only one column with highest vif value
# Out:
#    R&D Spend  Administration  Marketing Spend  Florida  New York  intercept
# 0  165349.20       136897.80        471784.10        0         1          1
# 1  162597.70       151377.59        443898.53        0         0          1
# 2  153441.51       101145.55        407934.54        1         0          1
# 3  144372.41       118671.85        383199.62        0         1          1
# 4  142107.34        91391.77        366168.42        1         0          1

# %%
VIF['vif']= [vif(x.values,i) for i in range(x.shape[1])]   # before executing this line reset VIF again. make it empty dataframe, by running VIF empty dataframe again

# %%
VIF
# Out:
#          vif
# 0   2.495511
# 1   1.177766
# 2   2.416797
# 3   1.387641
# 4   1.335061
# 5  26.600153

# %%
VIF[VIF['vif']<3]
# Out:
#         vif
# 0  2.495511
# 1  1.177766
# 2  2.416797
# 3  1.387641
# 4  1.335061

# %%
VIF[VIF['vif']>3]
# Out:
#          vif
# 5  26.600153
